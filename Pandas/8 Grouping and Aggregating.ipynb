# %%
import pandas as pd

# %%
df = pd.read_csv("data\survey_results_public.csv", index_col="ResponseId")
schema_df = pd.read_csv("data\survey_results_schema.csv", index_col="qid")

# %%
schema_df.head(10)
# Out:
#                    qname                                           question  \
# qid
# QID16                 S0  <div><span style="font-size:19px;"><strong>Hel...
# QID12           MetaInfo                                  Browser Meta Info
# QID1                  S1  <span style="font-size:22px; font-family: aria...
# QID2          MainBranch  Which of the following options best describes ...
# QID296        Employment  Which of the following best describes your cur...
# QID308        RemoteWork  Which best describes your current work situation?
# QID297  CodingActivities  Which of the following best describes the code...
# QID190                S2  <span style="font-size:22px; font-family: aria...
# QID25            EdLevel  Which of the following best describes the high...
# QID276         LearnCode  How did you learn to code? Select all that apply.
#
#        force_resp  type selector
# qid
# QID16       False    DB       TB
# QID12       False  Meta  Browser
# ...

# %%
pd.set_option("display.max_columns", 79)
pd.set_option("display.max_rows", 100)

# %%
df.head(100)
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# 6           I am not primarily a developer, but I write co...
# 7                                 I code primarily as a hobby
# 8                              I am a developer by profession
# 9                              I am a developer by profession
# 10                             I am a developer by profession
# 11                             I am a developer by profession
# 12          I am not primarily a developer, but I write co...
# 13                             I am a developer by profession
# 14                             I am a developer by profession
# ...

# %%
# Access first 15 rows of column CompTotal

df["CompTotal"].head(15)
# Out:
# ResponseId
# 1          NaN
# 2          NaN
# 3      32000.0
# 4      60000.0
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9      46000.0
# 10         NaN
# 11     48000.0
# 12    194400.0
# 13     65000.0
# 14         NaN
# 15    110000.0
# Name: CompTotal, dtype: float64

# %%
# calculate median of CompTotal

df["CompTotal"].median()
# Out:
# 77500.0

# %%
df.median()
# Out:
# C:\Users\Ajay Singh\AppData\Local\Temp\ipykernel_7820\530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# CompTotal                    77500.0
# VCHostingPersonal use            NaN
# VCHostingProfessional use        NaN
# WorkExp                          8.0
# ConvertedCompYearly          67845.0
# dtype: float64

# %%
df.describe()
# Out:
#           CompTotal  VCHostingPersonal use  VCHostingProfessional use  \
# count  3.842200e+04                    0.0                        0.0
# mean   2.342434e+52                    NaN                        NaN
# std    4.591478e+54                    NaN                        NaN
# min    0.000000e+00                    NaN                        NaN
# 25%    3.000000e+04                    NaN                        NaN
# 50%    7.750000e+04                    NaN                        NaN
# 75%    1.540000e+05                    NaN                        NaN
# max    9.000000e+56                    NaN                        NaN
#
#             WorkExp  ConvertedCompYearly
# count  36769.000000         3.807100e+04
# mean      10.242378         1.707613e+05
# std        8.706850         7.814132e+05
# min        0.000000         1.000000e+00
# 25%        4.000000         3.583200e+04
# 50%        8.000000         6.784500e+04
# 75%       15.000000         1.200000e+05
# ...

# %%
df["CompTotal"].count()
# Out:
# 38422

# %%
df.columns
# Out:
# Index(['MainBranch', 'Employment', 'RemoteWork', 'CodingActivities', 'EdLevel',
#        'LearnCode', 'LearnCodeOnline', 'LearnCodeCoursesCert', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'PurchaseInfluence', 'BuyNewTool',
#        'Country', 'Currency', 'CompTotal', 'CompFreq',
#        'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith',
#        'OpSysProfessional use', 'OpSysPersonal use', 'VersionControlSystem',
#        'VCInteraction', 'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %%
df["Country"]
# Out:
# ResponseId
# 1                                                      NaN
# 2                                                   Canada
# 3        United Kingdom of Great Britain and Northern I...
# 4                                                   Israel
# 5                                 United States of America
#                                ...
# 73264                                              Nigeria
# 73265                             United States of America
# 73266                             United States of America
# 73267    United Kingdom of Great Britain and Northern I...
# 73268                                               Canada
# Name: Country, Length: 73268, dtype: object

# %%
df["Country"].value_counts()
# Out:
# United States of America                                13543
# India                                                    6639
# Germany                                                  5395
# United Kingdom of Great Britain and Northern Ireland     4190
# Canada                                                   2490
#                                                         ...
# Monaco                                                      1
# Djibouti                                                    1
# Seychelles                                                  1
# Solomon Islands                                             1
# Saint Kitts and Nevis                                       1
# Name: Country, Length: 180, dtype: int64

# %%
# Grouping By working pattern (Split Object, Apply Function and Combine Results)

country_grp = df.groupby(["Country"])

# %%
country_grp.get_group("United States of America")
# Out:
#                                                    MainBranch  \
# ResponseId
# 5                              I am a developer by profession
# 12          I am not primarily a developer, but I write co...
# 13                             I am a developer by profession
# 15                             I am a developer by profession
# 27                             I am a developer by profession
# ...                                                       ...
# 73232                             I code primarily as a hobby
# 73241                          I am a developer by profession
# 73255       I am not primarily a developer, but I write co...
# 73265                          I am a developer by profession
# 73266       I am not primarily a developer, but I write co...
#
#                                                    Employment  \
# ResponseId
# 5                                         Employed, full-time
# 12          Employed, full-time;Independent contractor, fr...
# ...

# %%
country_grp.get_group("India")
# Out:
#                                                    MainBranch  \
# ResponseId
# 7                                 I code primarily as a hobby
# 8                              I am a developer by profession
# 66                             I am a developer by profession
# 141                            I am a developer by profession
# 152                            I am a developer by profession
# ...                                                       ...
# 73185                          I am a developer by profession
# 73194       I used to be a developer by profession, but no...
# 73256                          I am a developer by profession
# 73258                                   I am learning to code
# 73259                          I am a developer by profession
#
#                                     Employment  \
# ResponseId
# 7                           Student, part-time
# 8           Not employed, but looking for work
# 66                         Employed, full-time
# ...

# %%
filt = df["Country"] == "India"
df.loc[filt]
# Out:
#                                                    MainBranch  \
# ResponseId
# 7                                 I code primarily as a hobby
# 8                              I am a developer by profession
# 66                             I am a developer by profession
# 141                            I am a developer by profession
# 152                            I am a developer by profession
# ...                                                       ...
# 73185                          I am a developer by profession
# 73194       I used to be a developer by profession, but no...
# 73256                          I am a developer by profession
# 73258                                   I am learning to code
# 73259                          I am a developer by profession
#
#                                     Employment  \
# ResponseId
# 7                           Student, part-time
# 8           Not employed, but looking for work
# 66                         Employed, full-time
# ...

# %%
country_grp["SOAccount"].value_counts().head(10)
# Out:
# Country      SOAccount
# Afghanistan  Yes                        46
#              Not sure/can't remember    12
#              No                          9
# Albania      Yes                        44
#              No                          8
#              Not sure/can't remember     6
# Algeria      Yes                        31
#              Not sure/can't remember     3
#              No                          2
# Andorra      Yes                         7
# Name: SOAccount, dtype: int64

# %%
country_grp['ConvertedCompYearly'].median()
# Out:
# Country
# Afghanistan                             10894.0
# Albania                                 15360.0
# Algeria                                  7440.0
# Andorra                                 76784.0
# Angola                                   3073.5
#                                          ...
# Venezuela, Bolivarian Republic of...    12000.0
# Viet Nam                                11388.0
# Yemen                                   15000.0
# Zambia                                   6612.0
# Zimbabwe                                11400.0
# Name: ConvertedCompYearly, Length: 180, dtype: float64

# %%
# Get median salary of germany

country_grp['ConvertedCompYearly'].median().loc["Germany"]
# Out:
# 69318.0

# %%
# Get mean median by country

country_grp['ConvertedCompYearly'].agg(["median","mean"])
# Out:
#                                        median          mean
# Country
# Afghanistan                           10894.0  33914.666667
# Albania                               15360.0  24895.148148
# Algeria                                7440.0  12732.888889
# Andorra                               76784.0  98003.125000
# Angola                                 3073.5   6222.750000
# ...                                       ...           ...
# Venezuela, Bolivarian Republic of...  12000.0  17079.400000
# Viet Nam                              11388.0  37707.563830
# Yemen                                 15000.0  17464.666667
# Zambia                                 6612.0   8452.000000
# Zimbabwe                              11400.0  87596.000000
#
# [180 rows x 2 columns]

# %%
country_grp['ConvertedCompYearly'].agg(["median","mean"]).loc["Canada"]
# Out:
# median     93701.000000
# mean      228742.255908
# Name: Canada, dtype: float64

# %%
# Find out python developers in India

filt = df['Country'] == "India"
df.loc[filt]["LanguageHaveWorkedWith"].str.contains('Python')
# Out:
# ResponseId
# 7         True
# 8        False
# 66       False
# 141      False
# 152       True
#          ...
# 73185     True
# 73194    False
# 73256    False
# 73258     True
# 73259    False
# Name: LanguageHaveWorkedWith, Length: 6639, dtype: object

# %%
# Total number of people that have worked with python in India

filt = df['Country'] == "India"
df.loc[filt]["LanguageHaveWorkedWith"].str.contains('Python').sum()
# Out:
# 3081

# %%
country_grp["LanguageHaveWorkedWith"].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              25
# Albania                                  19
# Algeria                                  19
# Andorra                                   4
# Angola                                    3
#                                        ...
# Venezuela, Bolivarian Republic of...     52
# Viet Nam                                136
# Yemen                                     4
# Zambia                                    6
# Zimbabwe                                 11
# Name: LanguageHaveWorkedWith, Length: 180, dtype: int64

# %%
country_respondents = df["Country"].value_counts()
country_respondents
# Out:
# United States of America                                13543
# India                                                    6639
# Germany                                                  5395
# United Kingdom of Great Britain and Northern Ireland     4190
# Canada                                                   2490
#                                                         ...
# Monaco                                                      1
# Djibouti                                                    1
# Seychelles                                                  1
# Solomon Islands                                             1
# Saint Kitts and Nevis                                       1
# Name: Country, Length: 180, dtype: int64

# %%
country_uses_python=country_grp["LanguageHaveWorkedWith"].apply(lambda x: x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                              25
# Albania                                  19
# Algeria                                  19
# Andorra                                   4
# Angola                                    3
#                                        ...
# Venezuela, Bolivarian Republic of...     52
# Viet Nam                                136
# Yemen                                     4
# Zambia                                    6
# Zimbabwe                                 11
# Name: LanguageHaveWorkedWith, Length: 180, dtype: int64

# %%
python_df = pd.concat([country_respondents, country_uses_python], axis='columns', sort=False)
python_df
# Out:
#                                                     Country  \
# United States of America                              13543
# India                                                  6639
# Germany                                                5395
# United Kingdom of Great Britain and Northern Ir...     4190
# Canada                                                 2490
# ...                                                     ...
# Monaco                                                    1
# Djibouti                                                  1
# Seychelles                                                1
# Solomon Islands                                           1
# Saint Kitts and Nevis                                     1
#
#                                                     LanguageHaveWorkedWith
# United States of America                                              7017
# India                                                                 3081
# ...

# %%
python_df.rename(columns={"Country": "NumRespondents", "LanguageHaveWorkedWith":"NumKnowsPython"}, inplace=True)

# %%
python_df
# Out:
#                                                     NumRespondents  \
# United States of America                                     13543
# India                                                         6639
# Germany                                                       5395
# United Kingdom of Great Britain and Northern Ir...            4190
# Canada                                                        2490
# ...                                                            ...
# Monaco                                                           1
# Djibouti                                                         1
# Seychelles                                                       1
# Solomon Islands                                                  1
# Saint Kitts and Nevis                                            1
#
#                                                     NumKnowsPython
# United States of America                                      7017
# ...

# %%
# find out percentage of people who knows python 

python_df['PctKnowsPython'] = (python_df["NumKnowsPython"]/python_df["NumRespondents"]) * 100
python_df
# Out:
#                                                     NumRespondents  \
# United States of America                                     13543
# India                                                         6639
# Germany                                                       5395
# United Kingdom of Great Britain and Northern Ir...            4190
# Canada                                                        2490
# ...                                                            ...
# Monaco                                                           1
# Djibouti                                                         1
# Seychelles                                                       1
# Solomon Islands                                                  1
# Saint Kitts and Nevis                                            1
#
#                                                     NumKnowsPython  \
# United States of America                                      7017
# ...

# %%
python_df.sort_values(by="PctKnowsPython", ascending=False, inplace=True)
python_df
# Out:
#                        NumRespondents  NumKnowsPython  PctKnowsPython
# Saint Kitts and Nevis               1               1           100.0
# Brunei Darussalam                   1               1           100.0
# Burkina Faso                        1               1           100.0
# Fiji                                2               2           100.0
# Papua New Guinea                    2               2           100.0
# ...                               ...             ...             ...
# Sierra Leone                        2               0             0.0
# San Marino                          1               0             0.0
# Monaco                              1               0             0.0
# Djibouti                            1               0             0.0
# Seychelles                          1               0             0.0
#
# [180 rows x 3 columns]

# %%
python_df.loc['Russian Federation']
# Out:
# NumRespondents    1229.000000
# NumKnowsPython     590.000000
# PctKnowsPython      48.006509
# Name: Russian Federation, dtype: float64
